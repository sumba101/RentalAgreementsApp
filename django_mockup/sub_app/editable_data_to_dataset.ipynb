# %%
import os
import json
import pandas as pd

from semantic_search import *

# %%
editable_data_dir = os.path.join('data', 'editable-data')
dataset_dir = os.path.join('data', 'dataset')

# %%
def make_clauses_dict(input_dir=editable_data_dir, output_dir=dataset_dir):
    with open(os.path.join(input_dir, 'clause-list.txt'), 'r') as f:
        formal_list_content = f.read()
    
    clause_id_dict = dict()
    for split in formal_list_content.strip().split('\n\n'):
        clause_id, clause = split.strip().split('\n')
        clause_id = int(clause_id.strip())
        clause = clause.strip()
        clause_id_dict[clause_id] = clause
        
    if not os.path.exists(dataset_dir):
        os.makedirs(dataset_dir)

    with open(os.path.join(output_dir, 'clauses.json'), 'w') as f:
        json.dump(clause_id_dict, f)
    
    return clause_id_dict

# %%
def make_query_clause_dataset(clause_id_dict, input_dir=editable_data_dir, output_dir=dataset_dir):
    query_clause_dir = os.path.join(input_dir, 'query-clause')
    files = os.listdir(query_clause_dir)
    files.sort(key=lambda f : int(f[:-4]))
    query_clause_dicts = list()

    for file in files:
        with open(os.path.join(query_clause_dir, file), 'r') as f:
            query_clause_content = f.read().strip()

        valid_splits = list()
        for split in query_clause_content.split('\n'):
            split = split.strip()
            if split:
                valid_splits.append(split)

        clause_id = int(valid_splits[0])
        queries = valid_splits[2:]

        for i, query in enumerate(queries):
            query_clause_dict = dict()
            query_clause_dict['id'] = clause_id * 100 + i
            query_clause_dict['clause_id'] = clause_id
            query_clause_dict['query'] = query
            query_clause_dict['clause'] = clause_id_dict[clause_id]
            query_clause_dicts.append(query_clause_dict)
            
    with open(os.path.join(output_dir, 'query-to-clause.jsonl'), 'w') as f:
        for query_clause_dict in query_clause_dicts:
            query_clause_string = json.dumps(query_clause_dict)
            f.write(query_clause_string + '\n')
        
    return query_clause_dicts

# %%
def make_dataset(input_dir=editable_data_dir, output_dir=dataset_dir):
    clause_id_dict = make_clauses_dict(input_dir, output_dir)
    query_clause_dicts = make_query_clause_dataset(clause_id_dict, input_dir, output_dir)
    
    return clause_id_dict, query_clause_dicts

# %%
def load_clauses_dict(dataset_dir=dataset_dir):
    with open(os.path.join(dataset_dir, 'clauses.json'), 'r') as f:
        clauses_dict = json.load(f)
        
    return clauses_dict

# %%
def load_query_clause_dataset(dataset_dir=dataset_dir, as_pandas=True):
    with open(os.path.join(dataset_dir, 'query-to-clause.jsonl'), 'r') as f:
        query_clauses = pd.read_json(f, lines=True) if as_pandas else json.load(f)
    
    return query_clauses

# %%
def load_dataset(dataset_dir=dataset_dir, query_clause_as_pandas=True):
    clauses_dict = load_clauses_dict(dataset_dir)
    query_clauses = load_query_clause_dataset(dataset_dir, as_pandas=query_clause_as_pandas)
    
    return clauses_dict, query_clauses

# %%
clauses_dict, query_clauses = make_dataset()
len(clauses_dict.keys()), len(query_clauses)
# Out:
# (45, 49)

# %%
clauses_dict, query_clauses = load_dataset()
query_clauses
# Out:
#       id  clause_id                                              query  \
# 0    100          1  Remove any major changes to house before leaving.
# 1    200          2      Take license if you're carrying out business.
# 2    201          2  Make sure you're having a license if doing som...
# 3    300          3   I won't provide any insurance or security cover.
# 4    400          4                          Stay good with neighbors.
# 5    500          5  The house is in good condition, as you agree w...
# 6    600          6  Keep the house clean, take care of all the gad...
# 7    700          7  Please see to it that no damage is caused by y...
# 8    800          8         Please keep moving and cleaning the lawns.
# 9    900          9  You'll have to have a landline for yourself, a...
# 10  1000         10  Do not keep any materials that can lead to fir...
# 11  1100         11                         I'll pay the property tax.
# 12  1200         12                 You don't have to pay any advance.
# 13  1300         13  Me or my agent shall visit to inspect for wear...
# 14  1400         14                  We both will take a copy of this.
# 15  1500         15         I will increase the rent by 5% every year.
# 16  1600         16  Please don't ask for any compensation for anyt...
# 17  1700         17  You are not rented for forever, so do not expe...
# 18  1800         18                Please dump all the trash properly.
# 19  1900         19                                      No pets here.
# 20  2000         20       There will be no more than 5 people staying.
# 21  2100         21        Do not make noise that would bother others.
# 22  2200         22                             Dont smoke at my home.
# 23  2201         22                                 No smoking please.
# 24  2202         22                                      Do not smoke.
# 25  2203         22  I will not like the tenant to smoke on the pre...
# 26  2300         23  If there is any outage, it's not my responsibi...
# 27  2400         24  For the AC, plese don't set the temperature be...
# 28  2500         25  I am not responsible for any injury or damage ...
# 29  2600         26  Insurance on the property does not cover your ...
# 30  2700         27  You'll pay the costs involved in making this a...
# 31  2800         28     I haven't included daily maid service in rent.
# 32  2900         29  I have paid for cable tv as per my service lev...
# 33  3000         30  You have to pay all the service charges incurred.
# 34  3100         31  Let us both respect each other's rights and no...
# 35  3200         32   Use the flat only for the reason you are rented.
# 36  3300         33      Do not make any changes without my permission
# 37  3400         34                       Use the house only for stay.
# 38  3500         35                           Do not sublet the house.
# 39  3600         36                        Do not create any nuisance.
# 40  3700         37          Do not bring any anti-social person here.
# 41  3800         38        Do not be noisy so as to disturb neighbors.
# 42  3900         39  Do not have any inflammable substances at the ...
# 43  4000         40  I am open to renewal if things go favourable a...
# 44  4100         41   Please keep the kitched drains free of clogging.
# 45  4200         42                    Dispose all the waste properly.
# 46  4300         43     I will cancel lease if the terms are violated.
# 47  4400         44  Return all the equipmets in working condition ...
# 48  4500         45         You have to pay the costs due to clogging.
#
#                                                clause
# 0   The tenant shall at the termination of this ag...
# 1   The tenant shall himself obtain the license fo...
# 2   The tenant shall himself obtain the license fo...
# 3   All kinds of security arrangements insurances ...
# 4   The tenant shall keep good relationship with n...
# 5   The tenant acknowledges that the premises are ...
# 6   The tenant shall, at his own expense, and at a...
# 7   The tenant shall be responsible for damages ca...
# 8   The tenant shall mow, irrigate and maintain an...
# 9   The tenant shall obtain a home telephone and m...
# 10  No goods or materials of any kind or descripti...
# 11  The owner shall pay the property tax on the ho...
# 12  The tenant shall not pay any advance to the pr...
# 13  The owner or his authorized agent shall be per...
# 14  The tenant & owner both have retained a copy o...
# 15  The rent shall be increased by ____ % (____ Pe...
# 16  No compensation has to be claimed by the tenan...
# 17  The tenants expressly acknowledge and agree th...
# 18  The tenants shall dispose of all waste materia...
# 19  No animals or pets of any kind will be brought...
# 20  The tenants shall have no more than ____ perso...
# 21  The tenants shall not create noise or disturba...
# 22     There shall be no smoking inside the premises.
# 23     There shall be no smoking inside the premises.
# 24     There shall be no smoking inside the premises.
# 25     There shall be no smoking inside the premises.
# 26  The property occasionally experiences outages ...
# 27  The tenant agrees that air conditioning shall ...
# 28  The tenants and tenants' guests shall hereby i...
# 29  The tenants expressly recognize that any insur...
# 30  The tenants agree to pay all reasonable costs,...
# 31  Daily maid service is not included in the rent...
# 32  Cable TV is provided and service level has bee...
# 33  The tenant shall pay for all utilities and ser...
# 34  The owner shall have full control over the sup...
# 35  The tenant shall not use the demised premises ...
# 36  Tenant shall not make any changes without writ...
# 37  The tenant shall use the premise only for resi...
# 38  The tenant shall not sublet or sublease the po...
# 39  The tenant shall not create any untoward distu...
# 40  The tenant shall not allow any anti-social per...
# 41  The tenant agrees to not cause or allow any no...
# 42  The tenant shall not keep or store any illegal...
# 43  The tenancy may be renewed for further period/...
# 44  The tenant will take the responsibility to kee...
# 45  The tenants will dispose all waste material la...
# 46  The lease shall stand automatically terminated...
# 47  The tenant shall surrender all the equipments ...
# 48  The costs for clogging if any shall be borne b...
